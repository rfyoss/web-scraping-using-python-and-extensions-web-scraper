# %% [markdown]
# # SCRAPING E-COMMERCE USING WEB SCRAPER

# %%
df = pd.read_csv('lazada.csv')
df.head()

# %%
print(df.columns)

# %%
new_column_names = ['Order ID', 'Start URL', 'Product Name', 'Price', 'Location', 'Sold Count', 'Rating', 'Discount Percentage', 'Discount Value', 'Image 1', 'Image 2', 'Image 3', 'Image 4', 'Image 5']
df.columns = new_column_names
display(df.head())

# %%
df.to_csv('Lazada.csv', index=False)
print('Dataset `Lazada.csv` downloaded successfully.')

# %%
df1 = pd.read_csv('Lazada.csv')
df1.head()

# %%
df1.tail()

# %% [markdown]
# # SCRAPING USING PYTHON

# %%
# !pip install playwright pandas openpyxl
# !playwright install chromium
# Out:
# ...
# |                                                                                |   0% of 139.3 MiB
# |â– â– â– â– â– â– â– â–                                                                         |  10% of 139.3 MiB
# |â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â–                                                                 |  20% of 139.3 MiB
# |â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â–                                                         |  30% of 139.3 MiB
# |â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â–                                                 |  40% of 139.3 MiB
# |â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â–                                         |  50% of 139.3 MiB
# ...

# %%
import json
import time
import random
import csv
from datetime import datetime
from playwright.sync_api import sync_playwright, TimeoutError as PlaywrightTimeout

# %%
import sys; print(sys.version)
# Out:
# 3.8.2 (default, May  6 2020, 09:02:42) [MSC v.1916 64 bit (AMD64)]

# %%
# !playwright install firefox
# Out:
# ...
# |                                                                                |   0% of 84.8 MiB
# |â– â– â– â– â– â– â– â–                                                                         |  10% of 84.8 MiB
# |â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â–                                                                 |  20% of 84.8 MiB
# |â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â–                                                         |  30% of 84.8 MiB
# |â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â–                                                 |  40% of 84.8 MiB
# |â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â– â–                                         |  50% of 84.8 MiB
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "http://www.hubertiming.com/results/2017GPTR10K"
html = urlopen(url)

# %%
soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# Get the title
title = soup.title
print(title)
# Out:
# <title>Race results for the 2017 Intel Great Place to Run \ Urban Clash Games!</title>

# %%
# Print out the text
text = soup.get_text()
#print(soup.text)

# %%
soup.find_all('a')
# Out:
# [<a href="mailto:timing@hubertiming.com">timing@hubertiming.com</a>,
#  <a href="https://www.hubertiming.com">Huber Timing Home</a>,
#  <a class="btn btn-primary btn-lg" href="/results/2017GPTR" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-user"></i> 5K Individual</a>,
#  <a class="btn btn-primary btn-lg" href="/results/team/2017GPTR" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-users"></i> 5K Team</a>,
#  <a class="btn btn-primary btn-lg" href="/results/team/2017GPTR10K" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-users"></i> 10K Team</a>,
#  <a class="btn btn-primary btn-lg" href="/results/summary/2017GPTR10K" role="button" style="margin: 0px 0px 5px 5px"><i class="fa fa-stream"></i> Summary</a>,
#  <a id="individual" name="individual"></a>,
#  <a data-url="/results/2017GPTR10K" href="#tabs-1" id="rootTab" style="font-size: 18px">10K Results</a>,
# ...

# %%
all_links = soup.find_all("a")
for link in all_links:
    print(link.get("href"))
# Out:
# mailto:timing@hubertiming.com
# https://www.hubertiming.com
# /results/2017GPTR
# /results/team/2017GPTR
# /results/team/2017GPTR10K
# /results/summary/2017GPTR10K
# None
# #tabs-1
# https://www.hubertiming.com/
# https://facebook.com/hubertiming/

# %%
# Print the first 10 rows for sanity check
rows = soup.find_all('tr')
print(rows[:10])
# Out:
# [<tr colspan="2">
# <b>10K:</b>
# </tr>, <tr>
# <td>Finishers:</td>
# <td>577</td>
# </tr>, <tr>
# <td>Male:</td>
# <td>414</td>
# </tr>, <tr>
# <td>Female:</td>
# <td>163</td>
# </tr>, <tr class="header">
# <th>Place</th>
# <th>Bib</th>
# <th>Name</th>
# <th>Gender</th>
# <th>City</th>
# <th>State</th>
# <th>Time</th>
# <th>Gun Time</th>
# <th>Team</th>
# </tr>, <tr class="" data-bib="814">
# <td>1</td>
# <td>814</td>
# <td>
#
#                     JARED WILSON
#
#                 </td>
# <td>M</td>
# <td>TIGARD</td>
# <td>OR</td>
# <td>36:21</td>
# <td>36:24</td>
# <td></td>
# </tr>, <tr class="" data-bib="573">
# <td>2</td>
# <td>573</td>
# <td>
#
#                     NATHAN A SUSTERSIC
#
#                 </td>
# <td>M</td>
# <td>PORTLAND</td>
# <td>OR</td>
# <td>36:42</td>
# <td>36:45</td>
# <td>
# <img class="lazy teamThumbs" data-src="/teamLogoThumbnail/logo?teamName=INTEL%20TEAM%20F&amp;raceId=1251&amp;state=OR"/>
#                             INTEL TEAM F
# ...

# %%
for row in rows:
    row_td = row.find_all('td')
print(row_td)
type(row_td)
# Out:
# [<td>577</td>, <td>443</td>, <td>
#
#                     LIBBY B MITCHELL
#
#                 </td>, <td>F</td>, <td>HILLSBORO</td>, <td>OR</td>, <td>1:41:18</td>, <td>1:42:10</td>, <td></td>]
# bs4.element.ResultSet

# %%
str_cells = str(row_td)
cleantext = BeautifulSoup(str_cells, "lxml").get_text()
print(cleantext)
# Out:
# [577, 443,
#
#                     LIBBY B MITCHELL
#
#                 , F, HILLSBORO, OR, 1:41:18, 1:42:10, ]

# %%
import re

list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)
print(clean2)
type(clean2)
# Out:
# [577, 443,
#
#                     LIBBY B MITCHELL
#
#                 , F, HILLSBORO, OR, 1:41:18, 1:42:10, ]
# str

# %%
df = pd.DataFrame(list_rows)
df.head(20)
# Out:
#                                                     0
# 0                                                  []
# 1                                   [Finishers:, 577]
# 2                                        [Male:, 414]
# 3                                      [Female:, 163]
# 4                                                  []
# 5   [1, 814, \r\n\r\n                    JARED WIL...
# 6   [2, 573, \r\n\r\n                    NATHAN A ...
# 7   [3, 687, \r\n\r\n                    FRANCISCO...
# 8   [4, 623, \r\n\r\n                    PAUL MORR...
# 9   [5, 569, \r\n\r\n                    DEREK G O...
# 10  [6, 642, \r\n\r\n                    JONATHON ...
# 11  [7, 144, \r\n\r\n                    GEORGE TO...
# 12  [8, 395, \r\n\r\n                    BENJAMIN ...
# 13  [9, 7, \r\n\r\n                    BRANDON THO...
# 14  [10, 3, \r\n\r\n                    ERIK BJORN...
# 15  [11, 68, \r\n\r\n                    WITALI SP...
# ...
